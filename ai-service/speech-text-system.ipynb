# %%
exec(open("/ai-service/setup_colab.py").read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_526/4164690770.py in <cell line: 0>()
# ----> 1 exec(open("/ai-service/setup_colab.py").read())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/ai-service/setup_colab.py'

# %%
# %ls
# %ls ../home/code/github.com/verna990/fyp-project/speech-to-text
# Out:
# sample_data/
# ls: cannot access '../home/code/github.com/verna990/fyp-project/speech-to-text': No such file or directory

# %%
# !pip install torchao --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 19.7 MB/s eta 0:00:00

# %%
exec(open("/content/drive/MyDrive/speech-to-text-system/ai-service/master.py").read())
